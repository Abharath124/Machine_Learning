# %% [markdown]
# ## Class Multiple Linear Regression

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('house_prices_multiple_factor.csv')
df.head()
# Out:
#    House Size  Bedrooms  Age of House  House Price
# 0        1500         3            10       350000
# 1        1800         3             8       400000
# 2        2000         4             5       450000
# 3        2200         4             2       475000
# 4        2500         5            15       525000

# %%
x = df[['House Size','Bedrooms','Age of House']]
Y = df['House Price']

# %%
x_train,x_test,Y_train,Y_test = train_test_split(x,Y,test_size = 0.2,random_state = 42)

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
mse = mean_squared_error(Y_test,y_pred)

# %%
mse
# Out:
# 1339989534.2115455

# %%
print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)
print("Mean Squared Error:",mse)
# Out:
# Coefficients: [  158.08101415 39179.58602014 -1375.99244475]
# Intercept: -64531.6887172095
# Mean Squared Error: 1339989534.2115455

# %%
sns.scatterplot(x=Y_test, y=y_pred)
plt.plot([min(Y_test), max(Y_test)], [min(Y_test), max(Y_test)], color='red')
plt.xlabel("Actual House Price")
plt.ylabel("Predicted House Price")
plt.title("Actual vs Predicted Prices")

plt.show()
